# %% [markdown]
# # ⚽ SIMULADO 2.0: Machine Learning com Analogia do Futebol 🧠
#
# ## 📋 **Segunda Rodada - Questões Avançadas!**
#
# **Contexto:** Agora você é o diretor técnico de uma academia de futebol e precisa usar ML para desenvolver jovens talentos!
#
# **Novos Personagens:**
# - **Técnico Carlos (Random Forest)**: Usa vários "olheiros" para decidir
# - **Técnico Ana (SVM)**: Encontra a melhor "linha divisória" entre bons e ruins
# - **Técnico João (Naive Bayes)**: Continua analisando independentemente
# - **Técnico Pedro (KNN)**: Ainda compara jogadores similares
#
# **Novidades neste simulado:**
# - ✨ Questões mais avançadas
# - 🎯 Cenários mais complexos
# - 🧠 Conceitos de ensemble e validação
# - 📊 Interpretação de métricas avançadas
#
# **Bora para a segunda rodada!** 🚀
#
# ---

# %%
import numpy as np
import pandas as pd
from IPython.display import display, HTML
import random

# Função melhorada para mostrar questões
def mostrar_questao_v2(numero, pergunta, opcoes, dica=""):
    print(f"⚽ QUESTÃO {numero} - NÍVEL AVANÇADO")
    print("="*55)
    print(f"{pergunta}\n")
    
    if dica:
        print(f"💡 DICA: {dica}\n")
    
    for letra, opcao in opcoes.items():
        print(f"{letra}) {opcao}")
    print("\n" + "="*55)

# Sistema de pontuação melhorado
respostas_usuario_v2 = {}

print("🏆 SIMULADO 2.0 CARREGADO!")
print("⚡ Questões mais desafiadoras te aguardam!")
print("📝 Prepare-se para o próximo nível!")
# Out:
# 🏆 SIMULADO 2.0 CARREGADO!
# ⚡ Questões mais desafiadoras te aguardam!
# 📝 Prepare-se para o próximo nível!

# %% [markdown]
# ---

# %%
# QUESTÃO 1 - AVANÇADA
mostrar_questao_v2(1, 
    "Sua academia tem 3 categorias de dados de jogadores:\n" +
    "📊 CATEGORIA A: Altura, Peso, Idade (escala pequena)\n" +
    "💰 CATEGORIA B: Salário, Transferências (escala muito grande)\n" +
    "⚽ CATEGORIA C: Gols, Assistências, Passes (escala média)\n\n" +
    "Você aplicou StandardScaler. O que aconteceu?",
    {
        "A": "Apenas Categoria B foi normalizada, A e C permaneceram iguais",
        "B": "Todas as categorias ficaram com média=0 e desvio=1",
        "C": "Categoria A virou negativa, B e C ficaram positivas",
        "D": "StandardScaler não funciona com dados mistos"
    },
    "Pense no que o StandardScaler faz com CADA feature individualmente"
)

print("SUA RESPOSTA: B")
# Out:
# ⚽ QUESTÃO 1 - NÍVEL AVANÇADO
# ...
# Sua academia tem 3 categorias de dados de jogadores:
# 📊 CATEGORIA A: Altura, Peso, Idade (escala pequena)
# 💰 CATEGORIA B: Salário, Transferências (escala muito grande)
# ⚽ CATEGORIA C: Gols, Assistências, Passes (escala média)
#
# Você aplicou StandardScaler. O que aconteceu?
#
# 💡 DICA: Pense no que o StandardScaler faz com CADA feature individualmente
#
# A) Apenas Categoria B foi normalizada, A e C permaneceram iguais
# B) Todas as categorias ficaram com média=0 e desvio=1
# C) Categoria A virou negativa, B e C ficaram positivas
# D) StandardScaler não funciona com dados mistos
#
# ...
# SUA RESPOSTA: B

# %%
# QUESTÃO 2 - AVANÇADA
mostrar_questao_v2(2,
    "Você dividiu 2000 jogadores em: 60% treino, 20% validação, 20% teste.\n" +
    "Durante cross-validation, você descobriu que K=7 é o melhor.\n" +
    "Agora precisa fazer a avaliação final. Qual sequência está CORRETA?",
    {
        "A": "Treinar com 60% + validar com 20% + testar com 20%",
        "B": "Treinar com 80% (treino+validação) + testar com 20%",
        "C": "Treinar apenas com 60% + testar com 40% (validação+teste)",
        "D": "Usar todos os 100% para treinar o modelo final"
    },
    "Após escolher hiperparâmetros, como usar TODOS os dados disponíveis para treino?"
)

print("SUA RESPOSTA: B")
# Out:
# ⚽ QUESTÃO 2 - NÍVEL AVANÇADO
# ...
# Você dividiu 2000 jogadores em: 60% treino, 20% validação, 20% teste.
# Durante cross-validation, você descobriu que K=7 é o melhor.
# Agora precisa fazer a avaliação final. Qual sequência está CORRETA?
#
# 💡 DICA: Após escolher hiperparâmetros, como usar TODOS os dados disponíveis para treino?
#
# A) Treinar com 60% + validar com 20% + testar com 20%
# B) Treinar com 80% (treino+validação) + testar com 20%
# C) Treinar apenas com 60% + testar com 40% (validação+teste)
# D) Usar todos os 100% para treinar o modelo final
#
# ...
# SUA RESPOSTA: B

# %%
# QUESTÃO 3 - AVANÇADA
mostrar_questao_v2(3,
    "Você testou KNN com diferentes métricas de distância:\n" +
    "🔹 Euclidiana: 85% de acurácia\n" +
    "🔹 Manhattan: 88% de acurácia\n" +
    "🔹 Minkowski: 87% de acurácia\n\n" +
    "Por que Manhattan pode ter performado melhor?",
    {
        "A": "Manhattan é sempre superior à Euclidiana em qualquer dataset",
        "B": "Manhattan é menos sensível a outliers extremos nas características",
        "C": "Manhattan funciona melhor apenas com dados categóricos",
        "D": "A diferença é insignificante e deve ser ignorada"
    },
    "Pense em como cada métrica calcula distância e reage a valores extremos"
)

print("SUA RESPOSTA: B")
# Out:
# ⚽ QUESTÃO 3 - NÍVEL AVANÇADO
# ...
# Você testou KNN com diferentes métricas de distância:
# 🔹 Euclidiana: 85% de acurácia
# 🔹 Manhattan: 88% de acurácia
# 🔹 Minkowski: 87% de acurácia
#
# Por que Manhattan pode ter performado melhor?
#
# 💡 DICA: Pense em como cada métrica calcula distância e reage a valores extremos
#
# A) Manhattan é sempre superior à Euclidiana em qualquer dataset
# B) Manhattan é menos sensível a outliers extremos nas características
# C) Manhattan funciona melhor apenas com dados categóricos
# D) A diferença é insignificante e deve ser ignorada
#
# ...
# SUA RESPOSTA: B

# %%
# QUESTÃO 4 - AVANÇADA
mostrar_questao_v2(4,
    "Comparando algoritmos na sua academia de futebol:\n" +
    "⚡ Naive Bayes: Treino 89%, Validação 87% (gap: 2%)\n" +
    "⚡ KNN K=1: Treino 100%, Validação 74% (gap: 26%)\n" +
    "⚡ KNN K=15: Treino 82%, Validação 81% (gap: 1%)\n\n" +
    "Qual algoritmo tem o melhor trade-off bias-variance?",
    {
        "A": "KNN K=1 porque tem 100% no treino",
        "B": "Naive Bayes porque tem maior validação absoluta",
        "C": "KNN K=15 porque tem menor gap e boa generalização",
        "D": "Todos são equivalentes, escolher qualquer um"
    },
    "Gap pequeno = baixa variância, performance alta = baixo bias"
)

print("SUA RESPOSTA: C")
# Out:
# ⚽ QUESTÃO 4 - NÍVEL AVANÇADO
# ...
# Comparando algoritmos na sua academia de futebol:
# ⚡ Naive Bayes: Treino 89%, Validação 87% (gap: 2%)
# ⚡ KNN K=1: Treino 100%, Validação 74% (gap: 26%)
# ⚡ KNN K=15: Treino 82%, Validação 81% (gap: 1%)
#
# Qual algoritmo tem o melhor trade-off bias-variance?
#
# 💡 DICA: Gap pequeno = baixa variância, performance alta = baixo bias
#
# A) KNN K=1 porque tem 100% no treino
# B) Naive Bayes porque tem maior validação absoluta
# C) KNN K=15 porque tem menor gap e boa generalização
# D) Todos são equivalentes, escolher qualquer um
#
# ...
# SUA RESPOSTA: C

# %%
# QUESTÃO 5 - AVANÇADA
mostrar_questao_v2(5,
    "Sua matriz de confusão para detectar 'Jogadores Promissores':\n" +
    "📊 Verdadeiros Positivos: 85 (detectou corretamente promissores)\n" +
    "📊 Falsos Positivos: 20 (disse que era promissor, mas não era)\n" +
    "📊 Falsos Negativos: 15 (perdeu jogadores promissores)\n" +
    "📊 Verdadeiros Negativos: 80 (corretamente rejeitou não-promissores)\n\n" +
    "Qual métrica é mais importante para sua academia?",
    {
        "A": "Precision (85/105 = 81%) - poucos falsos alarmes",
        "B": "Recall (85/100 = 85%) - não perder talentos",
        "C": "Accuracy (165/200 = 82.5%) - performance geral",
        "D": "F1-Score (83%) - balanceamento entre precision e recall"
    },
    "Em academias, é pior perder um talento ou investir em alguém sem potencial?"
)

print("SUA RESPOSTA: B")
# Out:
# ⚽ QUESTÃO 5 - NÍVEL AVANÇADO
# ...
# Sua matriz de confusão para detectar 'Jogadores Promissores':
# 📊 Verdadeiros Positivos: 85 (detectou corretamente promissores)
# 📊 Falsos Positivos: 20 (disse que era promissor, mas não era)
# 📊 Falsos Negativos: 15 (perdeu jogadores promissores)
# 📊 Verdadeiros Negativos: 80 (corretamente rejeitou não-promissores)
#
# Qual métrica é mais importante para sua academia?
#
# 💡 DICA: Em academias, é pior perder um talento ou investir em alguém sem potencial?
#
# A) Precision (85/105 = 81%) - poucos falsos alarmes
# B) Recall (85/100 = 85%) - não perder talentos
# C) Accuracy (165/200 = 82.5%) - performance geral
# D) F1-Score (83%) - balanceamento entre precision e recall
#
# ...
# SUA RESPOSTA: B

# %%
# QUESTÃO 6 - AVANÇADA
mostrar_questao_v2(6,
    "Você implementou um pipeline complexo:\n" +
    "🔧 Pipeline(['scaler', StandardScaler()], ['pca', PCA(n_components=10)], ['knn', KNeighborsClassifier()])\n\n" +
    "Durante cross-validation, onde o PCA deve ser aplicado?",
    {
        "A": "Antes do split dos dados para ter componentes consistentes",
        "B": "Apenas no fold de treino, aplicando transformação no fold de validação",
        "C": "Nos dados completos uma vez, depois usar em todos os folds",
        "D": "PCA não deve ser usado com cross-validation"
    },
    "Data leakage: informação do futuro contaminando o presente"
)

print("SUA RESPOSTA: B")
# Out:
# ⚽ QUESTÃO 6 - NÍVEL AVANÇADO
# ...
# Você implementou um pipeline complexo:
# 🔧 Pipeline(['scaler', StandardScaler()], ['pca', PCA(n_components=10)], ['knn', KNeighborsClassifier()])
#
# Durante cross-validation, onde o PCA deve ser aplicado?
#
# 💡 DICA: Data leakage: informação do futuro contaminando o presente
#
# A) Antes do split dos dados para ter componentes consistentes
# B) Apenas no fold de treino, aplicando transformação no fold de validação
# C) Nos dados completos uma vez, depois usar em todos os folds
# D) PCA não deve ser usado com cross-validation
#
# ...
# SUA RESPOSTA: B

# %%
# QUESTÃO 7 - AVANÇADA
mostrar_questao_v2(7,
    "Resultados dos seus 'técnicos assistentes' em dados desequilibrados:\n" +
    "📈 Dataset: 10% jogadores promissores, 90% jogadores comuns\n" +
    "📈 Modelo ingênuo: 90% accuracy (sempre prediz 'comum')\n" +
    "📈 Seu modelo: 85% accuracy, mas detecta 70% dos promissores\n\n" +
    "Qual modelo é melhor?",
    {
        "A": "Modelo ingênuo porque tem maior accuracy",
        "B": "Seu modelo porque detecta a classe minoritária importante",
        "C": "São equivalentes, 5% de diferença é irrelevante",
        "D": "Impossível decidir sem mais informações"
    },
    "Em classes desequilibradas, accuracy pode ser enganosa"
)

print("SUA RESPOSTA: B")
# Out:
# ⚽ QUESTÃO 7 - NÍVEL AVANÇADO
# ...
# Resultados dos seus 'técnicos assistentes' em dados desequilibrados:
# 📈 Dataset: 10% jogadores promissores, 90% jogadores comuns
# 📈 Modelo ingênuo: 90% accuracy (sempre prediz 'comum')
# 📈 Seu modelo: 85% accuracy, mas detecta 70% dos promissores
#
# Qual modelo é melhor?
#
# 💡 DICA: Em classes desequilibradas, accuracy pode ser enganosa
#
# A) Modelo ingênuo porque tem maior accuracy
# B) Seu modelo porque detecta a classe minoritária importante
# C) São equivalentes, 5% de diferença é irrelevante
# D) Impossível decidir sem mais informações
#
# ...
# SUA RESPOSTA: B

# %%
# QUESTÃO 8 - AVANÇADA
mostrar_questao_v2(8,
    "Você está comparando algoritmos com Learning Curves:\n" +
    "📊 Com 100 amostras: Treino 95%, Validação 60%\n" +
    "📊 Com 500 amostras: Treino 90%, Validação 75%\n" +
    "📊 Com 1000 amostras: Treino 87%, Validação 82%\n" +
    "📊 Com 2000 amostras: Treino 85%, Validação 84%\n\n" +
    "O que está acontecendo?",
    {
        "A": "Modelo está piorando com mais dados",
        "B": "Overfitting diminuindo, generalização melhorando",
        "C": "Algoritmo não é adequado para este problema",
        "D": "Dados estão contaminados ou com ruído"
    },
    "Observe a tendência: gap diminuindo e validação subindo"
)

print("SUA RESPOSTA: B")
# Out:
# ⚽ QUESTÃO 8 - NÍVEL AVANÇADO
# ...
# Você está comparando algoritmos com Learning Curves:
# 📊 Com 100 amostras: Treino 95%, Validação 60%
# 📊 Com 500 amostras: Treino 90%, Validação 75%
# 📊 Com 1000 amostras: Treino 87%, Validação 82%
# 📊 Com 2000 amostras: Treino 85%, Validação 84%
#
# O que está acontecendo?
#
# 💡 DICA: Observe a tendência: gap diminuindo e validação subindo
#
# A) Modelo está piorando com mais dados
# B) Overfitting diminuindo, generalização melhorando
# C) Algoritmo não é adequado para este problema
# D) Dados estão contaminados ou com ruído
#
# ...
# SUA RESPOSTA: B

# %%
# QUESTÃO 9 - AVANÇADA
mostrar_questao_v2(9,
    "Implementando Ensemble com seus técnicos assistentes:\n" +
    "🎯 Técnico João (Naive Bayes): 82% individual\n" +
    "🎯 Técnico Pedro (KNN): 85% individual\n" +
    "🎯 Técnico Carlos (Random Forest): 87% individual\n" +
    "🎯 Voting Classifier (maioria): 89% combinado\n\n" +
    "Por que o ensemble superou os modelos individuais?",
    {
        "A": "Sempre acontece, ensemble é matematicamente superior",
        "B": "Erros diferentes se cancelam, diversidade ajuda",
        "C": "Random Forest já é ensemble, duplicou o efeito",
        "D": "Coincidência, não há garantia teórica"
    },
    "Wisdom of crowds: opiniões diversas e independentes"
)

print("SUA RESPOSTA: C")
# Out:
# ⚽ QUESTÃO 9 - NÍVEL AVANÇADO
# ...
# Implementando Ensemble com seus técnicos assistentes:
# 🎯 Técnico João (Naive Bayes): 82% individual
# 🎯 Técnico Pedro (KNN): 85% individual
# 🎯 Técnico Carlos (Random Forest): 87% individual
# 🎯 Voting Classifier (maioria): 89% combinado
#
# Por que o ensemble superou os modelos individuais?
#
# 💡 DICA: Wisdom of crowds: opiniões diversas e independentes
#
# A) Sempre acontece, ensemble é matematicamente superior
# B) Erros diferentes se cancelam, diversidade ajuda
# C) Random Forest já é ensemble, duplicou o efeito
# D) Coincidência, não há garantia teórica
#
# ...
# SUA RESPOSTA: C

# %%
# QUESTÃO 10 - AVANÇADA
mostrar_questao_v2(10,
    "Situação final: Deploy do modelo em produção na academia!\n" +
    "⚡ Modelo escolhido: KNN com K=5, StandardScaler, accuracy 91%\n" +
    "⚡ Em produção: Performance caiu para 78% após 3 meses\n" +
    "⚡ Investigação: Novos jogadores têm perfil diferente\n\n" +
    "Qual é o problema e a solução?",
    {
        "A": "Overfitting - treinar com mais dados históricos",
        "B": "Data drift - retreinar com dados recentes",
        "C": "Algoritmo inadequado - mudar para Random Forest",
        "D": "Erro de implementação - verificar código"
    },
    "Mundo real muda, modelos precisam acompanhar"
)

print("SUA RESPOSTA: B")
# Out:
# ⚽ QUESTÃO 10 - NÍVEL AVANÇADO
# ...
# Situação final: Deploy do modelo em produção na academia!
# ⚡ Modelo escolhido: KNN com K=5, StandardScaler, accuracy 91%
# ⚡ Em produção: Performance caiu para 78% após 3 meses
# ⚡ Investigação: Novos jogadores têm perfil diferente
#
# Qual é o problema e a solução?
#
# 💡 DICA: Mundo real muda, modelos precisam acompanhar
#
# A) Overfitting - treinar com mais dados históricos
# B) Data drift - retreinar com dados recentes
# C) Algoritmo inadequado - mudar para Random Forest
# D) Erro de implementação - verificar código
#
# ...
# SUA RESPOSTA: B

# %% [markdown]
# ---
#
# ## 🏆 **GABARITO AVANÇADO - SIMULADO 2.0**
#
# Execute a célula abaixo para ver as respostas e explicações detalhadas!

# %%
def mostrar_gabarito_v2():
    gabarito_avancado = {
        1: {"resposta": "B", "explicacao": "StandardScaler transforma CADA feature independentemente para média=0 e desvio=1, independente da escala original. Todas as categorias ficam normalizadas."},
        
        2: {"resposta": "B", "explicacao": "Após escolher hiperparâmetros com cross-validation, combine treino+validação (80%) para treinar o modelo final, testando apenas nos 20% finais."},
        
        3: {"resposta": "B", "explicacao": "Manhattan (L1) soma diferenças absolutas, sendo menos sensível a outliers que Euclidiana (L2) que eleva ao quadrado as diferenças."},
        
        4: {"resposta": "C", "explicacao": "KNN K=15 tem baixo gap (1%) indicando baixa variância, e performance razoável (81%) indicando bias aceitável. Melhor trade-off."},
        
        5: {"resposta": "B", "explicacao": "Em academias, perder um talento (falso negativo) é mais grave que investir em alguém sem potencial. Recall é crucial para não perder oportunidades."},
        
        6: {"resposta": "B", "explicacao": "PCA deve ser fit apenas no treino de cada fold para evitar data leakage. O pipeline automaticamente aplica isso corretamente."},
        
        7: {"resposta": "B", "explicacao": "Com classes desequilibradas, accuracy pode ser enganosa. Seu modelo detecta a classe importante (promissores) que o ingênuo ignora completamente."},
        
        8: {"resposta": "B", "explicacao": "Learning curve mostra overfitting diminuindo: gap entre treino e validação reduz, validação melhora. Mais dados ajudam generalização."},
        
        9: {"resposta": "B", "explicacao": "Ensemble funciona quando modelos fazem erros diferentes. Diversidade permite que erros individuais se cancelem, melhorando performance geral."},
        
        10: {"resposta": "B", "explicacao": "Data drift: distribuição dos dados mudou ao longo do tempo. Solução é retreinar com dados recentes para capturar novos padrões."}
    }
    
    print("🏆 GABARITO SIMULADO 2.0 - NÍVEL AVANÇADO")
    print("="*65)
    
    for questao, info in gabarito_avancado.items():
        print(f"\n⚽ QUESTÃO {questao}")
        print(f"✅ RESPOSTA: {info['resposta']}")
        print(f"🧠 EXPLICAÇÃO: {info['explicacao']}")
        print("-" * 55)
    
    print("\n🎖️ SISTEMA DE AVALIAÇÃO AVANÇADO:")
    print("🥇 9-10 acertos: MACHINE LEARNING EXPERT! 🚀")
    print("🥈 7-8 acertos: PRATICANTE AVANÇADO! 💪")
    print("🥉 5-6 acertos: BOM CONHECIMENTO! 📈")
    print("📚 3-4 acertos: CONTINUE ESTUDANDO! 📖")
    print("🔄 0-2 acertos: REVISE OS FUNDAMENTOS! 🎯")

# Execute para ver o gabarito
mostrar_gabarito_v2()
# Out:
# 🏆 GABARITO SIMULADO 2.0 - NÍVEL AVANÇADO
# ...
#
# ⚽ QUESTÃO 1
# ✅ RESPOSTA: B
# 🧠 EXPLICAÇÃO: StandardScaler transforma CADA feature independentemente para média=0 e desvio=1, independente da escala original. Todas as categorias ficam normalizadas.
# -------------------------------------------------------
#
# ⚽ QUESTÃO 2
# ✅ RESPOSTA: B
# 🧠 EXPLICAÇÃO: Após escolher hiperparâmetros com cross-validation, combine treino+validação (80%) para treinar o modelo final, testando apenas nos 20% finais.
# -------------------------------------------------------
#
# ⚽ QUESTÃO 3
# ✅ RESPOSTA: B
# 🧠 EXPLICAÇÃO: Manhattan (L1) soma diferenças absolutas, sendo menos sensível a outliers que Euclidiana (L2) que eleva ao quadrado as diferenças.
# -------------------------------------------------------
#
# ⚽ QUESTÃO 4
# ✅ RESPOSTA: C
# 🧠 EXPLICAÇÃO: KNN K=15 tem baixo gap (1%) indicando baixa variância, e performance razoável (81%) indicando bias aceitável. Melhor trade-off.
# ...

# %% [markdown]
# ---
#
# ## 🎯 **CORREÇÃO AUTOMÁTICA - SIMULADO 2.0**
#
# Digite suas respostas e veja sua pontuação!

# %%
def calcular_pontuacao_v2():
    # Digite suas 10 respostas
    suas_respostas = input("Digite suas 10 respostas (exemplo: ABCDABCDAB): ").upper()
    
    gabarito_v2 = "BBCBCBBBBB"
    
    if len(suas_respostas) != 10:
        print("❌ Erro: Digite exatamente 10 respostas!")
        return
    
    acertos = 0
    areas_problema = []
    
    print("\n📊 ANÁLISE DETALHADA - SIMULADO 2.0:")
    print("="*45)
    
    # Mapeamento de questões para áreas
    areas_questoes = {
        1: "Feature Engineering",
        2: "Metodologia ML", 
        3: "Algoritmos Avançados",
        4: "Bias-Variance Trade-off",
        5: "Métricas e Avaliação",
        6: "Pipelines e Data Leakage",
        7: "Classes Desequilibradas",
        8: "Learning Curves",
        9: "Ensemble Methods",
        10: "MLOps e Produção"
    }
    
    for i in range(10):
        questao = i + 1
        sua_resp = suas_respostas[i]
        correta = gabarito_v2[i]
        area = areas_questoes[questao]
        
        if sua_resp == correta:
            print(f"✅ Q{questao} ({area}): {sua_resp} - CORRETO!")
            acertos += 1
        else:
            print(f"❌ Q{questao} ({area}): {sua_resp} (Correto: {correta})")
            areas_problema.append(area)
    
    pontuacao = (acertos / 10) * 100
    
    print("\n" + "="*45)
    print(f"🎯 RESULTADO FINAL: {acertos}/10 ({pontuacao:.0f}%)")
    
    # Avaliação por nível
    if acertos >= 9:
        print("🥇 MACHINE LEARNING EXPERT! Você domina conceitos avançados!")
        print("🚀 Pronto para projetos complexos e liderança técnica!")
    elif acertos >= 7:
        print("🥈 PRATICANTE AVANÇADO! Excelente conhecimento!")
        print("💪 Continue se aprofundando nos tópicos mais complexos!")
    elif acertos >= 5:
        print("🥉 BOM CONHECIMENTO! Base sólida estabelecida!")
        print("📈 Foque nas áreas de melhoria identificadas!")
    elif acertos >= 3:
        print("📚 CONTINUE ESTUDANDO! Você está no caminho certo!")
        print("📖 Revise os conceitos fundamentais antes de avançar!")
    else:
        print("🔄 REVISE OS FUNDAMENTOS! Pratique mais os básicos!")
        print("🎯 Volte ao simulado 1.0 para consolidar a base!")
    
    # Feedback específico por área
    if areas_problema:
        print("\n💡 ÁREAS PARA APROFUNDAMENTO:")
        for area in set(areas_problema):
            print(f"📌 {area}")
    
    print("\n🎓 PARABÉNS POR COMPLETAR O NÍVEL AVANÇADO!")

# Execute e digite suas respostas
calcular_pontuacao_v2()
# Out:
# 📊 ANÁLISE DETALHADA - SIMULADO 2.0:
# ...
# ✅ Q1 (Feature Engineering): B - CORRETO!
# ✅ Q2 (Metodologia ML): B - CORRETO!
# ❌ Q3 (Algoritmos Avançados): B (Correto: C)
# ❌ Q4 (Bias-Variance Trade-off): C (Correto: B)
# ❌ Q5 (Métricas e Avaliação): B (Correto: C)
# ✅ Q6 (Pipelines e Data Leakage): B - CORRETO!
# ✅ Q7 (Classes Desequilibradas): B - CORRETO!
# ✅ Q8 (Learning Curves): B - CORRETO!
# ❌ Q9 (Ensemble Methods): C (Correto: B)
# ✅ Q10 (MLOps e Produção): B - CORRETO!
#
# ...
# 🎯 RESULTADO FINAL: 6/10 (60%)
# 🥉 BOM CONHECIMENTO! Base sólida estabelecida!
# 📈 Foque nas áreas de melhoria identificadas!
#
# 💡 ÁREAS PARA APROFUNDAMENTO:
# 📌 Métricas e Avaliação
# 📌 Bias-Variance Trade-off
# 📌 Ensemble Methods
# 📌 Algoritmos Avançados
#
# 🎓 PARABÉNS POR COMPLETAR O NÍVEL AVANÇADO!

# %% [markdown]
# ---
#
# ## 🧠 **CONCEITOS AVANÇADOS TESTADOS**
#
# ### ⚽ **Evolução da Analogia:**
# - **Academia de Futebol** = Ambiente de desenvolvimento contínuo
# - **Múltiplos Técnicos** = Ensemble de algoritmos
# - **Desenvolvimento de Talentos** = Otimização de modelos
# - **Produção/Deploy** = Aplicação no mundo real
#
# ### 🎯 **Tópicos Avançados Abordados:**
#
# 1. **Feature Engineering** - Normalização multi-escala
# 2. **Metodologia Rigorosa** - Train/Validation/Test correto
# 3. **Métricas de Distância** - Manhattan vs Euclidiana
# 4. **Bias-Variance Trade-off** - Análise de gaps
# 5. **Métricas Avançadas** - Precision, Recall, F1
# 6. **Data Leakage** - Pipelines seguros
# 7. **Classes Desequilibradas** - Limitações da accuracy
# 8. **Learning Curves** - Diagnóstico de overfitting
# 9. **Ensemble Methods** - Combinação de modelos
# 10. **MLOps** - Data drift e manutenção
#
# ### 🏆 **Próximos Desafios:**
# - **Score 9-10**: Explore deep learning e NLP
# - **Score 7-8**: Pratique com projetos end-to-end
# - **Score 5-6**: Aprofunde conceitos de validação
# - **Score 0-4**: Consolide fundamentos primeiro
#
# **Parabéns por enfrentar o desafio avançado! 🚀⚽**
